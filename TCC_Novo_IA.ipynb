# %% [markdown]
# <a href="https://colab.research.google.com/github/ANAMARIAZAVA/Detector_Afogamento_TCC/blob/main/TCC_Novo_IA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Passo 1: Instalação da biblioteca Ultralytics
# Isso baixa as ferramentas necessárias para os servidores do Google
# !pip install ultralytics

# Importa a biblioteca e verifica se o ambiente (CPU) está pronto
import ultralytics
ultralytics.checks()
# Out:
# Ultralytics 8.4.12 🚀 Python-3.12.12 torch-2.9.0+cpu CPU (Intel Xeon CPU @ 2.20GHz)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 21.2/107.7 GB disk)

# %%
# Carregando o modelo de IA
from ultralytics import YOLO

# Carregar o modelo YOLOv8n pré-treinado
model = YOLO('yolov8n.pt')

print("Modelo YOLOv8 Nano carregado com sucesso!")
# Out:
# ...
# Modelo YOLOv8 Nano carregado com sucesso!
